# %%
from textblob import TextBlob
import sys, tweepy
from tweepy import API

from tweepy import OAuthHandler

## Imported the Twitter API and the TextBLob which is a library for processing data

consumer_key = "4vfkAV19HTl3MWsWzERGmqaut"
consumer_secret = "qVkhJPOgk2XCOqQIVKOwdp0JXR6A1hTwvG9UFW7FmrZrusRB8c"
access_tokens = "394085841-K4JCh60Ex3gkew4g4vuIhwqR3hU6GdYp5nxJ4bn4"
access_token_secret = "KI89AiZtN7jQm7W89CI37mguC5yzfTbyqYZqKdUOkfG4f"

## Inserted the Twitter unique keys from the devloper account


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_tokens, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

## Called the API and initialized their value.


## Taking Input from the User.
search_term = input("Enter keyword to search about: ")
no_of_search_terms = int(input("Enter the number of tweets you want to analyze: "))

## Initialize the values.
positive = 0
negative = 0
neutral = 0
polarity = 0

# Call  the tweepy.

public_tweets = tweepy.Cursor(api.search, q=search_term).items(no_of_search_terms)


for tweet in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    polarity += analysis.sentiment.polarity
    print(analysis.sentiment)

    if(analysis.sentiment.polarity ==0):
        neutral += 1
    elif(analysis.sentiment.polarity < 0.00):
        negative += 1
    elif(analysis.sentiment.polarity > 0.00):
        positive += 1


def percentage(part, whole):
    return 100 * float(part) / float(whole)


positive = percentage(positive, no_of_search_terms)
neutral = percentage(neutral, no_of_search_terms)
negative = percentage(negative, no_of_search_terms)

positive = format(positive,'.2f')
neutral = format(neutral,'.2f')
negative = format(negative,'.2f')

## Get the observation how people are reacting to the searched keyword.

print("How people are reacting on " + search_term + " by analyzing " + str(no_of_search_terms) + " Tweets")
if(polarity == 0):
    print("Neutral")
elif(polarity < 0):
    print("Negative")
elif(polarity > 0):
    print("Positive")
# Out:
# Enter keyword to search about: injection
# Enter the number of tweets you want to analyze: 10
# The vaccine injection site on my arm is a little tender and swollen, but it’s probably just my body rejecting the microchip.
# Sentiment(polarity=-0.1875, subjectivity=0.5)
# RT @fionamflanagan1: When globalist leaders, former world leaders, politicians, medics, the entire MSM, the Queen, celebrities, blue tick i…
# Sentiment(polarity=0.0, subjectivity=0.24166666666666667)
# RT @fionamflanagan1: When globalist leaders, former world leaders, politicians, medics, the entire MSM, the Queen, celebrities, blue tick i…
# Sentiment(polarity=0.0, subjectivity=0.24166666666666667)
# RT @AlainLegaret: Je rencontre plein de gens qui ont accepté la double-injection non pour échapper au virus mais pour échapper aux mesures…
# Sentiment(polarity=0.0, subjectivity=0.0)
# at some point ima get up and do this injection
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @0gtweet: Do you trust RunAsPPL? The "prevent code injection that could compromise credentials" narration? Technically it is right, as y…
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# RT @itmedia_news: AWS、わざとクラウド障害を起こすサービス「AWS Fault Injection Simulator」提供開始
# https://t.co/CQGefge6e4
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @0gtweet: Do you trust RunAsPPL? The "prevent code injection that could compromise credentials" narration? Technically it is right, as y…
# Sentiment(polarity=0.2857142857142857, subjectivity=0.5357142857142857)
# RT @LouGarza86: Happy to report no real bad side effects after the 1st Pfizer shot other than a sore arm at the injection site and a very m…
# Sentiment(polarity=0.2770833333333333, subjectivity=0.5298611111111111)
# #HRNews As part of the effort to support the country's recovery, the Malaysian government yesterday launched the St… https://t.co/z5ZqAsagMF
# Sentiment(polarity=0.0, subjectivity=0.0)
# How people are reacting on injection by analyzing 10 Tweets
# Positive
